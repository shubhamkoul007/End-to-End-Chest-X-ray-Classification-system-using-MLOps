# %%
from box import ConfigBox

# %%
from ensure import ensure_annotations

# %%
### download data from google drive

# %% [markdown]
# ### Download data from gdrive

# %%
import gdown

# %%
url = "https://drive.google.com/file/d/13hvREGdBmYtgJaWq9st-s9rNFM9ysurU/view?usp=sharing"

# %%
type(url)
# Out:
# str

# %%
file_id = url.split("/")[-2]
file_id
# Out:
# '13hvREGdBmYtgJaWq9st-s9rNFM9ysurU'

# %%
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id, "Chest-CT-Scan-data.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=13hvREGdBmYtgJaWq9st-s9rNFM9ysurU
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=13hvREGdBmYtgJaWq9st-s9rNFM9ysurU&confirm=t&uuid=0708ac5e-9fc7-4daf-a9be-a77ac876b00c
# To: /Users/shubhamkoul/Documents/myProjects/End-to-End-Chest-X-ray-Classification-system-using-MLOps/research/Chest-CT-Scan-data.zip
# 100%|██████████| 49.0M/49.0M [00:05<00:00, 8.52MB/s]
# 'Chest-CT-Scan-data.zip'
